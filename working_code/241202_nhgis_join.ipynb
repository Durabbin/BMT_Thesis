# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
shp = gpd.read_file('/Users/raoulherskoits/Documents/GIS Work/BMT_Thesis/IPUMS/gis_extract_3/nhgis0003_shape/nhgis0003_shapefile_tl2000_us_tract_1960/US_tract_1960.shp')
df = pd.read_csv('/Users/raoulherskoits/Documents/GIS Work/BMT_Thesis/IPUMS/gis_extract_3/nhgis0003_csv/nhgis0003_ds92_1960_tract.csv')
# Out:
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_47169/387927524.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/raoulherskoits/Documents/GIS Work/BMT_Thesis/IPUMS/gis_extract_3/nhgis0003_csv/nhgis0003_ds92_1960_tract.csv')

# %%
shp['geometry']
# Out:
# 0        POLYGON ((651976.176 650755.333, 651982.799 65...
# 1        POLYGON ((650272.805 649747.585, 650282.766 64...
# 2        POLYGON ((650781.384 650653.887, 650797.438 65...
# 3        POLYGON ((649637.423 649761.016, 649556.686 64...
# 4        POLYGON ((649128.795 649717.968, 649031.916 64...
#                                ...
# 23091    POLYGON ((-6130207.517 290567.699, -6129977.13...
# 23092    POLYGON ((-6145830.394 313187.673, -6146077.86...
# 23093    POLYGON ((-6126670.408 270618.480, -6126634.58...
# 23094    POLYGON ((-6130266.039 292120.490, -6130226.72...
# 23095    POLYGON ((-6119191.656 268213.649, -6119073.56...
# Name: geometry, Length: 23096, dtype: geometry

# %%
mergedf = pd.merge(shp, df, on='GISJOIN', how='inner')
gdf = gpd.GeoDataFrame(mergedf)
# Out:
#       NHGISST NHGISCTY         GISJOIN       GISJOIN2    SHAPE_AREA  \
# 4389      360     0550    G36005500022    36005500022  5.760888e+05
# 4390      360     0550    G36005500048    36005500048  4.475476e+05
# 5021      360     0590  G3600590HE0052  3600590HE0052  9.045148e+05
# 5022      360     0550    G36005500012    36005500012  2.814543e+05
# 5023      360     0550    G36005500011    36005500011  1.898324e+05
# ...       ...      ...             ...            ...           ...
# 19433     360     0610    G36006100009    36006100009  2.453757e+05
# 19434     360     0610    G36006100011    36006100011  1.061908e+05
# 22756     360     0850    G36008500282    36008500282  5.582327e+04
# 22759     360     0850    G36008500223    36008500223  7.606403e+05
# 22785     360     0290    G36002900122    36002900122  5.181211e+06
#
#           SHAPE_LEN                                           geometry  YEAR  \
# ...

# %%
gdf = gdf.loc[(gdf['STATE']=='New York') & (gdf['COUNTY']=='Kings')]
