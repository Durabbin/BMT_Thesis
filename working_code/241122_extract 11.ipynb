# %% [markdown]
# # Raoul Herskovits Extract 10 Python Notebook
# ## Part 1: Package Importing, Data Cleaning and Reading

# %% [markdown]
# ## Package Importing, Data Cleaning and Reading

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import r2_score
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Our Data is an extract of census data from the Full Censuses of 1880 through 1940, isolated for only Kings County (Brooklyn) NY
#
# For more information about the extract, see the codebook in the repository.

# %%
# Read In Our Data and take a peek
df = pd.read_csv('/Users/raoulherskoits/Documents/GIS Work/THESIS/IPUMS extracts/microdata_extracts/extract_11/usa_00011.csv')

# %%
print("shape:", df.shape)
print('-------------')
print(df.dtypes)
print('-------------')
df.head()
# Out:
# shape: (7936470, 34)
# -------------
# YEAR             int64
# SAMPLE           int64
# SERIAL           int64
# HHWT           float64
# STATEFIP         int64
# COUNTYICP        int64
# GQ               int64
# ENUMDIST         int64
# PERNUM           int64
# SEX              int64
# AGE              int64
# RACE             int64
# RACED            int64
# HISPAN           int64
# HISPAND          int64
# BPL              int64
# BPLD             int64
# MBPL             int64
# MBPLD            int64
# FBPL             int64
# FBPLD            int64
# NATIVITY         int64
# OCC1950          int64
# IND1950          int64
# VERSIONHIST      int64
# HISTID          object
# MBPL_MOM       float64
# MBPL_POP       float64
# MBPL_MOM2      float64
# MBPL_POP2      float64
# FBPL_MOM       float64
# FBPL_POP       float64
# FBPL_MOM2      float64
# FBPL_POP2      float64
# dtype: object
# -------------
#    YEAR  SAMPLE   SERIAL  HHWT  STATEFIP  COUNTYICP  GQ  ENUMDIST  PERNUM  \
# 0  1880  188003  5999091   1.0        36        470   1  47000001       1
# 1  1880  188003  5999091   1.0        36        470   1  47000001       2
# 2  1880  188003  5999091   1.0        36        470   1  47000001       3
# 3  1880  188003  5999091   1.0        36        470   1  47000001       4
# 4  1880  188003  5999091   1.0        36        470   1  47000001       5
#
#    SEX  ...  VERSIONHIST                                HISTID  MBPL_MOM  \
# 0    2  ...            2  9FF5A2DD-D229-4B87-A50E-73957C2CFBC8       NaN
# 1    2  ...            2  6E9CB7D7-4B60-4551-B3FF-2E05A4CC280A      36.0
# 2    2  ...            2  F020F0B3-D539-43A5-9EFE-A6F5BCDF2E23      36.0
# 3    2  ...            2  CA33FAA3-9408-4037-A56F-7F09851FFBD1      36.0
# 4    2  ...            2  D0351FAD-DFF1-457A-82B1-D87F2AC514A2       NaN
#
#    MBPL_POP  MBPL_MOM2  MBPL_POP2  FBPL_MOM  FBPL_POP  FBPL_MOM2  FBPL_POP2
# 0       NaN        NaN        NaN       NaN       NaN        NaN        NaN
# 1       NaN        NaN        NaN      36.0       NaN        NaN        NaN
# 2       NaN        NaN        NaN      36.0       NaN        NaN        NaN
# 3       NaN        NaN        NaN      36.0       NaN        NaN        NaN
# 4       NaN        NaN        NaN       NaN       NaN        NaN        NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ### New Column Generation
# This data is microdata where all values in columns are codes referring to a specific classification.
# We can't just "get dummies" on a column because there are too many codes. We have to make our own dummies.

# %% [markdown]
# #### I. demographics

# %%
# Make columns for our three primary Ethnic/Racial Groups
df['ISPR'] = (
    (df['HISPAN']==2) #Checking Hispanic census variable for "Puerto Rican" category
    |(df['MBPL']==110)|(df['FBPL']==110) #Checking if mother or father is born 
    |((df['FBPL_POP']==110)&(df['MBPL_POP']==110)) #Checking grandparents birthplaces for PR 
    |((df['FBPL_MOM']==110)&(df['MBPL_MOM']==110))
    ).astype(int)
df['ISWHITE'] = (
    (df['RACE']==1) 
    & ((df['HISPAND']==000)|(df['HISPAND']==480)) #Including people from Spain as white
    ).astype(int) #Hispan 480 is Spanish, which we will include
df['ISBLACK'] = (df['RACE']==2).astype(int)

# %% [markdown]
# Checking for ethnicity within white communities is more difficult, especially as we get to 1930 and 1940, when members of the italian community have parents both born in the united states. This should not exclude them from our "Italian" designation, so we check for grandparents birthplace as well.

# %%
# Italian Identity Groups
df['ITALYBPL'] = (df['BPL']==434).astype(int)
df['ISITALIAN'] = (
    #Check for mothers, fathers, or own birthplace as italy
    (df['MBPL']==434)|(df['FBPL']==434)|(df['ITALYBPL']==1)
    #Check for grandparent birthplase as italy
    |((df['FBPL_POP']==434)&(df['MBPL_POP']==434))
    |((df['FBPL_MOM']==434)&(df['MBPL_MOM']==434))
    ).astype(int) #We'll categorize Italian as anyone with either a Mother or Father from Italy
df['ISWHITE_NON_ITALIAN'] = ((df['ISWHITE']==1)&(df['ISITALIAN']==0)).astype(int)

# German, Russian, and Irish
df['ISGERMAN'] = (
    (df['BPL']==453)|(df['MBPL']==453)|(df['FBPL']==453)
    |((df['FBPL_POP']==453)&(df['MBPL_POP']==453))
    |((df['FBPL_MOM']==453)&(df['MBPL_MOM']==453))
                  ).astype(int)
df['ISSLAVIC'] = (
    (df['BPL']==465)|(df['MBPL']==465)|(df['FBPL']==465)
    |((df['FBPL_POP']==465)&(df['MBPL_POP']==465))
    |((df['FBPL_MOM']==465)&(df['MBPL_MOM']==465))
    ).astype(int)
df['ISIRISH'] = (
    (df['BPL']==414)|(df['MBPL']==414)|(df['FBPL']==414)
    |((df['FBPL_POP']==414)&(df['MBPL_POP']==414))
    |((df['FBPL_MOM']==414)&(df['MBPL_MOM']==414))
    ).astype(int)


# Compiling major groups into one
df['DEMO_GROUP'] = 0
df.loc[df['ISIRISH']==1, 'DEMO_GROUP'] = 1
df.loc[df['ISSLAVIC']==1, 'DEMO_GROUP'] = 2
df.loc[df['ISGERMAN']==1, 'DEMO_GROUP'] = 3
df.loc[df['ISITALIAN']==1, 'DEMO_GROUP'] = 4
df.loc[df['ISBLACK']==1, 'DEMO_GROUP'] = 5
df.loc[df['ISPR']==1, 'DEMO_GROUP'] = 6

# Redefine our Demographic columns to eliminate overlap
df['IS_DEMO_0'] = (df['DEMO_GROUP']==0).astype(int)
df['ISIRISH'] = (df['DEMO_GROUP']==1).astype(int)
df['ISSLAVIC'] = (df['DEMO_GROUP']==2).astype(int)
df['ISGERMAN'] = (df['DEMO_GROUP']==3).astype(int)
df['ISITALIAN'] = (df['DEMO_GROUP']==4).astype(int)
df['ISBLACK'] = (df['DEMO_GROUP']==5).astype(int)
df['ISPR'] = (df['DEMO_GROUP']==6).astype(int)

# %% [markdown]
# #### II. employment

# %% [markdown]
# We start by separating the general occupation categories within the census (see the codebook for more details)

# %%
# make a column for people marked unemployed and people with no employment data

df['UNEMPLOYED'] = ((df['OCC1950'] < 997)&(df['OCC1950'] > 979)).astype(int) #as it turns out, very few people are listed as unemployed
df['OCC_UNKNOWN'] = (df['OCC1950'].isin([999, 997])).astype(int)


# Make a simplified version of the occupation data
df['OCC_CATEGORY'] = df['OCC1950']//100
df.loc[(df['UNEMPLOYED']==1), 'OCC_CATEGORY'] = 10
df.loc[(df['OCC_UNKNOWN']==1), 'OCC_CATEGORY'] = -1

# Get Dummies of this column, to isolate job category as a boolean variable per person
df['OCC_CATEGORY_DUMMY'] = df['OCC_CATEGORY']
df = pd.get_dummies(df, prefix=['OCC_CATEGORY'], columns=['OCC_CATEGORY_DUMMY'], dtype=int)

# %% [markdown]
# Rename the dummies to reflect their category

# %%
del df['OCC_CATEGORY_-1'] # we already have OCC_UNKNOWN
del df['OCC_CATEGORY_10'] # we already have UNEMPLOYED
df = df.rename(columns={
    'OCC_CATEGORY_0': 'OCC_Professional/Technical',
    'OCC_CATEGORY_1': 'OCC_Farmer',
    'OCC_CATEGORY_2': 'OCC_Manager, Official or Proprietor',
    'OCC_CATEGORY_3': 'OCC_Clerical and Kindred',
    'OCC_CATEGORY_4': 'OCC_Sales Worker',
    'OCC_CATEGORY_5': 'OCC_Craftsmen',
    'OCC_CATEGORY_6': 'OCC_Operative',
    'OCC_CATEGORY_7': 'OCC_Service Worker',
    'OCC_CATEGORY_8': 'OCC_Farm Laborer',
    'OCC_CATEGORY_9': 'OCC_Laborer', 
})

# %%
# Make a column for people working on the docks themselves (Longshoremen/Stevedores, Sailors/Deckhands), 
# and those in "water transportation" Industry
df['ISDOCKWORKER'] = ((df['OCC1950'].isin([940, 673]))|(df['IND1950']==546)).astype(int)


# Make a column for more general waterfront-related laborers

# Define generally waterfront-related job codes
# See Codebook for chosen occupations
waterfront_jobs = [920, 940, 950, 960, 673]
# Let's do the same for waterfront-related industries
# See codebook for chosen industries 
waterfront_industries = [546, 506, 527, 673, 378, 379]
# Create the column using both lists
df['ISWATERFRONT'] = ((df['OCC1950'].isin(waterfront_jobs)) | (df['IND1950'].isin(waterfront_industries))).astype(int)


# Make a more accurate column for all industrial laborers

# list of general industrial labor categories
# includes Construction, Mill work, misc woodwork, iron and steel work, machinery manufacturing, shipbuilding, 
# railroad and misc. transportation exuipment, misc. manufacturing, 
# transportation: Railroads and railway, Trucking service, Warehousing and storage, Water transportation,
# and "Common or General Laborer" and Sailors and deck hands
laborer_industries = [246, 307, 308, 336, 337, 358, 367, 376, 378, 379, 399, 506, 526, 527, 546, 976, 673]
df['ISINDUSTRY'] = ((df['OCC_CATEGORY']==9) | (df['IND1950'].isin(laborer_industries))).astype(int)


# Make a Column Aggregating These Job Categories

# since 'ISINDUSTRY' contains 'ISWATERFRONT' contains 'ISDOCKWORKER', we can do this by summing
df['JOB_GROUP'] = df[['ISINDUSTRY', 'ISWATERFRONT', 'ISDOCKWORKER']].sum(axis=1) + 1
# make a value for unemployed
df.loc[(df['JOB_GROUP']==1)&(df['UNEMPLOYED']==1), 'JOB_GROUP'] = 0
# make a value for unknown occupation
df.loc[df['OCC_UNKNOWN']==1, 'JOB_GROUP'] = -1

# %% [markdown]
# #### III. Other
# Boolean Columns for Group Quarters status, Immigrant statuse, and First Generation Immigrant Status (that is, if someone is the child of immigrants)

# %%
# make a column for whether or not they live in group quarters
df['ISGQ'] = (df['GQ']>2).astype(int)

# make columns based on immigrant status
df['ISIMMIGRANT'] = (df['NATIVITY']==5).astype(int)
df['ISGENONE'] = (df['NATIVITY'].isin([2, 3, 4])).astype(int) #for the children of immigrants

# %% [markdown]
# #### IV. Compound Columns
# Because we will need to aggregate our data when we merge with our shapefiles, we will need columns that represent a combination of attributes, namely demographic and employment.
#
# We will make two sets of Boolean columns check for combinations of two Distinct Columns:
# 1. DEMO_GROUP and OCC_CATEGORY
# 2. DEMO_GROUP and JOB_GROUP

# %% [markdown]
# pseudocode:
# for each combination of the two columns,
# make a new column expressing whether or not both are tro

# %%
df.columns
# Out:
# Index(['YEAR', 'SAMPLE', 'SERIAL', 'HHWT', 'STATEFIP', 'COUNTYICP', 'GQ',
#        'ENUMDIST', 'PERNUM', 'SEX', 'AGE', 'RACE', 'RACED', 'HISPAN',
#        'HISPAND', 'BPL', 'BPLD', 'MBPL', 'MBPLD', 'FBPL', 'FBPLD', 'NATIVITY',
#        'OCC1950', 'IND1950', 'VERSIONHIST', 'HISTID', 'MBPL_MOM', 'MBPL_POP',
#        'MBPL_MOM2', 'MBPL_POP2', 'FBPL_MOM', 'FBPL_POP', 'FBPL_MOM2',
#        'FBPL_POP2', 'ISPR', 'ISWHITE', 'ISBLACK', 'ITALYBPL', 'ISITALIAN',
#        'ISWHITE_NON_ITALIAN', 'ISGERMAN', 'ISSLAVIC', 'ISIRISH', 'DEMO_GROUP',
#        'IS_DEMO_0', 'UNEMPLOYED', 'OCC_UNKNOWN', 'OCC_CATEGORY',
#        'OCC_Professional/Technical', 'OCC_Farmer',
#        'OCC_Manager, Official or Proprietor', 'OCC_Clerical and Kindred',
#        'OCC_Sales Worker', 'OCC_Craftsmen', 'OCC_Operative',
#        'OCC_Service Worker', 'OCC_Farm Laborer', 'OCC_Laborer', 'ISDOCKWORKER',
#        'ISWATERFRONT', 'ISINDUSTRY', 'JOB_GROUP', 'ISGQ', 'ISIMMIGRANT',
#        'ISGENONE'],
#       dtype='object')

# %%
def checkboth(column1, column2):
    return ((df[column1] == 1) & (df[column2] == 1)).astype(int)

for demo in ['IS_DEMO_0', 'ISIRISH', 'ISSLAVIC', 'ISGERMAN', 'ISITALIAN', 'ISBLACK', 'ISPR']:
    for category in ['OCC_Professional/Technical', 'OCC_Farmer',
       'OCC_Manager, Official or Proprietor', 'OCC_Clerical and Kindred',
       'OCC_Sales Worker', 'OCC_Craftsmen', 'OCC_Operative',
       'OCC_Service Worker', 'OCC_Farm Laborer', 'OCC_Laborer', 'UNEMPLOYED', 'OCC_UNKNOWN']:
        df[f'{demo}_AND_{category}'] = checkboth(demo, category)
        print(df[f'{demo}_AND_{category}'].head(1))
    for category in ['ISDOCKWORKER','ISWATERFRONT', 'ISINDUSTRY']:
        df[f'{demo}_AND_{category}'] = checkboth(demo, category)
        print(df[f'{demo}_AND_{category}'].head(1))
# Out:
# 0    0
# Name: IS_DEMO_0_AND_OCC_Professional/Technical, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_OCC_Farmer, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_OCC_Manager, Official or Proprietor, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_OCC_Clerical and Kindred, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_OCC_Sales Worker, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_OCC_Craftsmen, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_OCC_Operative, dtype: int64
# 0    1
# Name: IS_DEMO_0_AND_OCC_Service Worker, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_OCC_Farm Laborer, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_OCC_Laborer, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_UNEMPLOYED, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_OCC_UNKNOWN, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_ISDOCKWORKER, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_ISWATERFRONT, dtype: int64
# 0    0
# Name: IS_DEMO_0_AND_ISINDUSTRY, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Professional/Technical, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Farmer, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Manager, Official or Proprietor, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Clerical and Kindred, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Sales Worker, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Craftsmen, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Operative, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Service Worker, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Farm Laborer, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_Laborer, dtype: int64
# 0    0
# Name: ISIRISH_AND_UNEMPLOYED, dtype: int64
# 0    0
# Name: ISIRISH_AND_OCC_UNKNOWN, dtype: int64
# 0    0
# Name: ISIRISH_AND_ISDOCKWORKER, dtype: int64
# 0    0
# Name: ISIRISH_AND_ISWATERFRONT, dtype: int64
# 0    0
# Name: ISIRISH_AND_ISINDUSTRY, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Professional/Technical, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Farmer, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Manager, Official or Proprietor, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Clerical and Kindred, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Sales Worker, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Craftsmen, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Operative, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Service Worker, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Farm Laborer, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_Laborer, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_UNEMPLOYED, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_OCC_UNKNOWN, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_ISDOCKWORKER, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_ISWATERFRONT, dtype: int64
# 0    0
# Name: ISSLAVIC_AND_ISINDUSTRY, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Professional/Technical, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Farmer, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Manager, Official or Proprietor, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Clerical and Kindred, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Sales Worker, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Craftsmen, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Operative, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Service Worker, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Farm Laborer, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_Laborer, dtype: int64
# 0    0
# Name: ISGERMAN_AND_UNEMPLOYED, dtype: int64
# 0    0
# Name: ISGERMAN_AND_OCC_UNKNOWN, dtype: int64
# 0    0
# Name: ISGERMAN_AND_ISDOCKWORKER, dtype: int64
# 0    0
# Name: ISGERMAN_AND_ISWATERFRONT, dtype: int64
# 0    0
# Name: ISGERMAN_AND_ISINDUSTRY, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Professional/Technical, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Farmer, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Manager, Official or Proprietor, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Clerical and Kindred, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Sales Worker, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Craftsmen, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Operative, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Service Worker, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Farm Laborer, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_Laborer, dtype: int64
# 0    0
# Name: ISITALIAN_AND_UNEMPLOYED, dtype: int64
# 0    0
# Name: ISITALIAN_AND_OCC_UNKNOWN, dtype: int64
# 0    0
# Name: ISITALIAN_AND_ISDOCKWORKER, dtype: int64
# 0    0
# Name: ISITALIAN_AND_ISWATERFRONT, dtype: int64
# 0    0
# Name: ISITALIAN_AND_ISINDUSTRY, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Professional/Technical, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Farmer, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Manager, Official or Proprietor, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Clerical and Kindred, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Sales Worker, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Craftsmen, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Operative, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Service Worker, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Farm Laborer, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_Laborer, dtype: int64
# 0    0
# Name: ISBLACK_AND_UNEMPLOYED, dtype: int64
# 0    0
# Name: ISBLACK_AND_OCC_UNKNOWN, dtype: int64
# 0    0
# Name: ISBLACK_AND_ISDOCKWORKER, dtype: int64
# 0    0
# Name: ISBLACK_AND_ISWATERFRONT, dtype: int64
# 0    0
# Name: ISBLACK_AND_ISINDUSTRY, dtype: int64
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# 0    0
# Name: ISPR_AND_OCC_Professional/Technical, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_Farmer, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_Manager, Official or Proprietor, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_Clerical and Kindred, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_Sales Worker, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_Craftsmen, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_Operative, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_Service Worker, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_Farm Laborer, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_Laborer, dtype: int64
# 0    0
# Name: ISPR_AND_UNEMPLOYED, dtype: int64
# 0    0
# Name: ISPR_AND_OCC_UNKNOWN, dtype: int64
# 0    0
# Name: ISPR_AND_ISDOCKWORKER, dtype: int64
# 0    0
# Name: ISPR_AND_ISWATERFRONT, dtype: int64
# 0    0
# Name: ISPR_AND_ISINDUSTRY, dtype: int64
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/752054708.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{demo}_AND_{category}'] = checkboth(demo, category)

# %% [markdown]
# ## Creating Trimmed-Down Dataframes
# I'd like to isolate only data where job information has been recorded, but first we need to make sure that no specific group has been disproportionately unreported

# %% [markdown]
# #### Make a DataFrame which isolates only the demographic groups we are trying to measure
# This dataframe will only be used for comparing these demographics, while the first dataframe will still be used for more general calculations

# %%
# A filtered dataframe which isolates our four primary demographic groups
df2 = df[df['DEMO_GROUP']!=0]
df2['DEMO_GROUP'].value_counts()
# Out:
# DEMO_GROUP
# 2    1197724
# 1    1072907
# 3    1005304
# 4     987149
# 5     192253
# 6      18885
# Name: count, dtype: int64

# %% [markdown]
# #### What about missing occupation data? Should we eliminate that?
# First, let's see what kind of job data is missing

# %%
# Make a graph depicting count of each racial group unemployed or uncategorized


# Group by DEMO_GROUP and OCC_UNKNOWN to count occurrences
group_counts = df.groupby(['DEMO_GROUP', 'OCC_UNKNOWN']).size().unstack(fill_value=0)

# Calculate the percentage of known and unknown data for each racial group
group_percentages = group_counts.div(group_counts.sum(axis=1), axis=0) * 100

# Plot the stacked bar chart
group_percentages.plot(kind='bar', stacked=True, color=['lightblue', 'salmon'], figsize=(10, 6))

# Customize the plot
plt.title("Percentage of Known vs. Unknown Employment Data by Racial Group")
plt.xlabel("Racial Group")
plt.ylabel("Percentage")
plt.xticks(ticks=[0, 1, 2, 3, 4, 5, 6], labels=["Other", "Irish", "Slavic", "German", "Italian", "Black", "Puerto Rican"], rotation=0)  # Customizing tick labels
plt.legend(["Known Employment", "Unknown Employment"], title="Employment Data")

plt.show()

# %% [markdown]
# It looks mostly even across demographic group. We will make a new dataframe of just recorded job groups, but again, this cannot replace our original dataframe, as populations with unreported occupation are very important

# %%
df_jobrecorded = df2[df2['JOB_GROUP']!=-1]
df_jobrecorded['OCC_CATEGORY'].value_counts()
# Out:
# OCC_CATEGORY
# 6     614963
# 5     433147
# 3     352150
# 9     349569
# 7     285283
# 2     225646
# 10    204686
# 4     202516
# 0     120635
# 1       6730
# 8       6312
# Name: count, dtype: int64

# %% [markdown]
# #### Make another new dataframe which simply compares our demographic and employment information
# This one compares our demographic category with our "OCC_CATEGORY" column, which is based off of the census' own categorization of labor forms

# %%
# Create the pivot table
dfcounts = df_jobrecorded.groupby(['DEMO_GROUP', 'OCC_CATEGORY']).size().reset_index().pivot_table(values=0,columns='OCC_CATEGORY',index=['DEMO_GROUP'])

dfcounts.columns = dfcounts.columns.get_level_values(0)

# Rename the columns to descriptive names
dfcounts = dfcounts.rename(columns={
    0: 'Professionals', 
    1: 'Farmers', 
    2: 'Managers, Officials, Proprietors', 
    3: 'Clerical and Kindred',  
    4: 'Sales workers',
    5: 'Craftsmen',
    6: 'Operatives',
    7: 'Service Workers',
    8: 'Farm Laborers',
    9: 'Laborers',
    10: 'Unemployed'
    },
                           index={1: 'Irish', 2: 'Slavic', 3: 'German',  4: 'Italian', 5: 'Black', 6: 'Puerto Rican'})


# We can also make the same dataframe display the percentages of each demographic group population in each labor category
dfpercentages = dfcounts.div(dfcounts.sum(axis=1), axis=0) * 100
dfpercentages
# Out:
# OCC_CATEGORY  Professionals   Farmers  Managers, Officials, Proprietors  \
# DEMO_GROUP
# Irish              4.472146  0.199750                          5.021216
# Slavic             6.033912  0.248108                         13.247687
# German             4.340301  0.259928                          8.408422
# Italian            2.466531  0.273290                          6.666824
# Black              2.488970  0.176336                          1.949455
# Puerto Rican       2.334163  0.214537                          2.574444
#
# OCC_CATEGORY  Clerical and Kindred  Sales workers  Craftsmen  Operatives  \
# DEMO_GROUP
# Irish                    15.663734       5.770314  13.427870   16.547904
# Slavic                   15.393062      11.934085  15.569529   23.550273
# German                   12.997484       7.968436  18.999401   19.376886
# Italian                   7.021814       4.087027  16.306753   30.566786
# Black                     4.181799       1.124801   5.620254   15.860522
# Puerto Rican              6.212992       2.042393   7.723333   32.094740
#
# OCC_CATEGORY  Service Workers  Farm Laborers   Laborers  Unemployed
# DEMO_GROUP
# Irish               13.629293       0.193756  13.932891   11.141127
# Slavic               2.925447       0.116790   6.493523    4.487584
# German               9.235353       0.192930   9.333834    8.887024
# Italian              7.604180       0.342330  19.847707    4.816757
# Black               45.441516       0.565027  17.524087    5.067233
# Puerto Rican        15.541062       0.660774  24.929203    5.672359

# %% [markdown]
# Lastly. Make a set of dataframes splitting our original dataframe by year. This will be useful when we merge our enumeration district shapefiles (whose labels are decade-specific) with our data.

# %%
df_1900 = df[df['YEAR']==1900]
df_1910 = df[df['YEAR']==1910]
df_1920 = df[df['YEAR']==1920]
df_1930 = df[df['YEAR']==1930]
df_1940 = df[df['YEAR']==1940]

# %% [markdown]
# ## Geography: Drawing and Linking

# %% [markdown]
# ### Drawing Enumeration Districts
# Enumeration District labels and boundaries changed every decade, and do not currently exist in a digital shapefile format. Using AncestryLibrary and the National Archives, I have drawn each district in our area of interest and assigned them their correct labels. More details on each year below.

# %% [markdown]
# #### 1900
# These district boundaries were available through AncestryLibrary:
#
# Ancestry.com. 1900 United States Federal Census [database on-line]. Lehi, UT, USA: Ancestry.com Operations Inc, 2004.
#
# https://www.ancestrylibrary.com/search/collections/7602/

# %%
shp1900 = gpd.read_file('/Users/raoulherskoits/Documents/GIS Work/Polygon Drawing/ED shapefiles/enumeration_districts_1900/enumeration_districts_1900.shp')
print(shp1900.head())
# Out:
#    1900label                                           geometry
# 0   47000168  POLYGON ((-74.01292 40.67732, -74.01142 40.676...
# 1   47000167  POLYGON ((-74.01416 40.67815, -74.01292 40.677...
# 2   47000169  POLYGON ((-74.01416 40.67815, -74.01224 40.679...
# 3   47000175  POLYGON ((-73.99873 40.67648, -73.99537 40.675...
# 4   47000176  POLYGON ((-74.00136 40.67575, -73.99933 40.675...

# %% [markdown]
# #### 1910
# These district boundaries were available through AncestryLibrary:
#
# Ancestry.com. 1910 United States Federal Census [database on-line]. Lehi, UT, USA: Ancestry.com Operations Inc, 2006.
#
# https://www.ancestrylibrary.com/search/collections/7884/

# %%
shp1910 = gpd.read_file('/Users/raoulherskoits/Documents/GIS Work/Polygon Drawing/ED shapefiles/enumeration_districts_1910/enumeration_districts_1910_projected.shp')
shp1910.head()
# Out:
#    1910label                                           geometry
# 0   47000240  POLYGON ((-74.01569 40.67251, -74.01726 40.673...
# 1   47000241  POLYGON ((-74.01331 40.67471, -74.01479 40.675...
# 2   47000242  POLYGON ((-74.01416 40.67815, -74.01142 40.676...
# 3   47000243  POLYGON ((-74.01103 40.67893, -74.00955 40.677...
# 4   47000244  POLYGON ((-74.01224 40.67979, -74.01103 40.678...

# %% [markdown]
# #### 1920
# These district boundaries were available through AncestryLibrary:
#
# Ancestry.com. 1920 United States Federal Census [database on-line]. Provo, UT, USA: Ancestry.com Operations, Inc., 2010. Images reproduced by FamilySearch.
#
# https://www.ancestrylibrary.com/search/collections/6061/

# %%
shp1920 = gpd.read_file('/Users/raoulherskoits/Documents/GIS Work/Polygon Drawing/ED shapefiles/enumeration_districts_1920/enumeration_districts_1920_projected.shp')
shp1920.head()
# Out:
#    id  1920label                                           geometry
# 0 NaN   47000124  POLYGON ((-74.00045 40.68964, -74.00074 40.689...
# 1 NaN   47000125  POLYGON ((-73.99787 40.68736, -73.99820 40.686...
# 2 NaN   47000126  POLYGON ((-73.99820 40.68667, -73.99908 40.684...
# 3 NaN   47000127  POLYGON ((-73.99896 40.68693, -73.99984 40.685...
# 4 NaN   47000128  POLYGON ((-74.00137 40.68771, -73.99989 40.687...

# %% [markdown]
# #### 1930
#
# These district boundaries were available through AncestryLibrary:
#
# Ancestry.com. 1930 United States Federal Census [database on-line]. Provo, UT, USA: Ancestry.com Operations Inc, 2002.
#
# https://www.ancestrylibrary.com/search/collections/6224/

# %%
shp1930 = gpd.read_file('/Users/raoulherskoits/Documents/GIS Work/Polygon Drawing/ED shapefiles/enumeration_districts_1930/enumeration_districts_1930_projected.shp')

del shp1930['1940label']
shp1930.head()
# Out:
#    1930label                                           geometry
# 0   47001710  POLYGON ((-74.01603 40.67656, -74.01753 40.677...
# 1   47000957  POLYGON ((-74.00366 40.68300, -74.00610 40.683...
# 2   47000975  POLYGON ((-74.01224 40.67979, -74.01103 40.678...
# 3   47000973  POLYGON ((-74.01603 40.67656, -74.01838 40.674...
# 4   47001716  POLYGON ((-74.00514 40.66789, -74.00355 40.671...

# %% [markdown]
# #### 1940

# %% [markdown]
# Comparing to the list of districts here:
# https://www.ancestrylibrary.com/search/collections/2442/
# we see that the majority of district names in the dataset end with 0 while most of the written ones end in another digit.

# %%
df.loc[(df['YEAR']==1940)&(df['ENUMDIST']%10 != 0)].groupby('ENUMDIST').size()
# Out:
# ENUMDIST
# 2400101    835
# 2400102    131
# 2400281    899
# 2400282    858
# 2400341    458
#           ...
# 2425902    103
# 2425921    893
# 2425922    669
# 2425931    130
# 2425932    188
# Length: 714, dtype: int64

# %%
df.loc[(df['YEAR']==1940)&(df['ENUMDIST']%10 == 0)].groupby('ENUMDIST').size()
# Out:
# ENUMDIST
# 2400010    1307
# 2400020     360
# 2400030     352
# 2400040      15
# 2400050     868
#            ...
# 2428590     471
# 2428600     487
# 2428610     430
# 2428620     407
# 2428630     422
# Length: 2446, dtype: int64

# %% [markdown]
# It seems as though district names are shifted one digit to the left to give room for another digit, used to designate a new differentiator used in this census: alphabetic codes at the end of some districts.
#
# e.g. enumeration district 1025:
# in the written districts, there are two districts 1025 (1025A and 1025B), and no districts 10251 or 10252. However in the dataset...

# %%
print(df.loc[(df['YEAR']==1940)&(df['ENUMDIST'] == 2401025)].groupby('ENUMDIST').size())
# There are no districts simply labeled 1025

print('\n ------------------- \n')

print(df.loc[(df['YEAR']==1940)&(df['ENUMDIST']//10==241025)].groupby('ENUMDIST').size())
# and there are are two districts 10251 and 10252!
# Out:
# Series([], dtype: int64)
#
#  -------------------
#
# ENUMDIST
# 2410251    793
# 2410252    723
# dtype: int64

# %% [markdown]
# This seems to be strong evidence that the last digit is reserved to designate the alphabetic label, and the label is not eliminated.
#
# We can try again with another district, 1031, which has three alphabetic designations: A, B, and C.

# %%
print('Rows with enumeration district ending in 1031:')

print(df.loc[(df['YEAR']==1940)&(df['ENUMDIST']%10000==1031)].groupby('ENUMDIST').size())

print('\n ------------------- \n')

print('Rows with enumeration district ending 1031 + another digit')
print(df.loc[(df['YEAR']==1940)&(df['ENUMDIST']//10==241031)].groupby('ENUMDIST').size())
# Out:
# Rows with enumeration district ending in 1031:
# Series([], dtype: int64)
#
#  -------------------
#
# Rows with enumeration district ending 1031 + another digit
# ENUMDIST
# 2410311    603
# 2410312    705
# 2410313    302
# dtype: int64

# %% [markdown]
# As we can see, the final digit once again matches the three alphabetic labels perfectly

# %%
df.loc[(df['YEAR']==1930)&(df['DEMO_GROUP']==6),'ENUMDIST'].value_counts()
# Out:
# ENUMDIST
# 47000931    323
# 47000947    280
# 47000948    242
# 47000951    214
# 47000940    207
#            ...
# 47000068      1
# 47001561      1
# 47000335      1
# 47000337      1
# 47001351      1
# Name: count, Length: 601, dtype: int64

# %% [markdown]
# With that knowledge, we can label our polygons correctly, and load them in.

# %%
shp1940 = gpd.read_file('/Users/raoulherskoits/Documents/GIS Work/Polygon Drawing/ED shapefiles/enumeration_districts_1940/enumeration_districts_1940_projected.shp')
shp1940.head()
# Out:
#    id  1940label                                           geometry
# 0 NaN    2404991  POLYGON ((-74.01142 40.67631, -74.00955 40.677...
# 1 NaN    2404992  POLYGON ((-74.00857 40.67643, -74.00808 40.676...
# 2 NaN    2404993  POLYGON ((-74.00681 40.67794, -74.00559 40.678...
# 3 NaN    2404994  POLYGON ((-74.00857 40.67643, -74.00833 40.676...
# 4 NaN    2404930  POLYGON ((-74.01603 40.67656, -74.01753 40.677...

# %% [markdown]
# #### Special Districts: Hostpitals/Schools
# There are a set of districts which are better mapped by points as opposed to polygons, as they refer to the property of specific institutions.

# %% [markdown]
# ## District Shape Concatenation

# %% [markdown]
# ### First, trim our Decade-Specific dataframes to only contain the data from our region of interest: Red Hook
# And rename their enumeration district labels to match those of the shapefiles

# %%
df_1900_redhook = df_1900[df_1900['ENUMDIST'].isin(shp1900['1900label'])]#.rename(columns={'ENUMDIST': '1900label'}, inplace=True)
df_1910_redhook = df_1910[df_1910['ENUMDIST'].isin(shp1910['1910label'])]#.rename(columns={'ENUMDIST': '1910label'}, inplace=True)
df_1920_redhook = df_1920[df_1920['ENUMDIST'].isin(shp1920['1920label'])]#.rename(columns={'ENUMDIST': '1920label'}, inplace=True)
df_1930_redhook = df_1930[df_1930['ENUMDIST'].isin(shp1930['1930label'])]#.rename(columns={'ENUMDIST': '1930label'}, inplace=True)
df_1940_redhook = df_1940[df_1940['ENUMDIST'].isin(shp1940['1940label'])]#.rename(columns={'ENUMDIST': '1940label'}, inplace=True)

# %% [markdown]
# ### Now, we make a function which produces two dataframes using the previously created ones:
# 1. a dataframe which adds "dummy" columns for OCC1950
# 2. an aggregated dataframe which counts all of our dummies in each enumeration district
#
# We will need to aggregate the grouped data before we merge with the shapefiles

# %%
def group_enum (df, shp, label):
    # Make dummies for occupation in case of future aggregation
    df['OCC1950_DUMMY'] = df['OCC1950']
    dummydf = pd.get_dummies(df, columns=['OCC1950_DUMMY'], prefix='OCC1950', dtype=int)
    
    # Prep our new dataframe
    dummydf = dummydf.loc[:,~dummydf.columns.duplicated()].copy() #gets rid of duplicate columns
    dummydf['TOTAL_POP'] = 1 #This can help in the future with counting population using aggregation
    dummydf.rename(columns={'ENUMDIST': label}, inplace=True)
    
    # Drop all non-aggregatable columns and group by Enumeration District
    trimdf = dummydf.drop(columns=['SAMPLE', 'SERIAL', 'HHWT', 'STATEFIP', 'COUNTYICP', 'GQ', 'PERNUM', 'SEX', 'AGE', 'RACE', 'RACED', 'HISPAN',
       'HISPAND', 'BPL', 'BPLD', 'MBPL', 'MBPLD', 'FBPL', 'FBPLD',
       'NATIVITY', 'OCC1950', 'IND1950', 'VERSIONHIST', 'HISTID',
       'MBPL_MOM', 'MBPL_POP', 'MBPL_MOM2', 'MBPL_POP2', 'FBPL_MOM',
       'FBPL_POP', 'FBPL_MOM2', 'FBPL_POP2', 'DEMO_GROUP', 'OCC_CATEGORY', 'JOB_GROUP'])
    # print(trimdf.head())
    aggdf = trimdf.groupby(label).sum().reset_index()
    print(aggdf.columns[aggdf.columns.duplicated()])    
    return dummydf, aggdf


df_1900_occdummies, df_1900_enumgroupsums = group_enum(df_1900_redhook, shp1900, '1900label')
df_1910_occdummies, df_1910_enumgroupsums = group_enum(df_1910_redhook, shp1910, '1910label')
df_1920_occdummies, df_1920_enumgroupsums = group_enum(df_1920_redhook, shp1920, '1920label')
df_1930_occdummies, df_1930_enumgroupsums = group_enum(df_1930_redhook, shp1930, '1930label')
df_1940_occdummies, df_1940_enumgroupsums = group_enum(df_1940_redhook, shp1940, '1940label')
# Out:
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/3323285916.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OCC1950_DUMMY'] = df['OCC1950']
# Index([], dtype='object')
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/3323285916.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OCC1950_DUMMY'] = df['OCC1950']
# Index([], dtype='object')
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/3323285916.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OCC1950_DUMMY'] = df['OCC1950']
# Index([], dtype='object')
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/3323285916.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OCC1950_DUMMY'] = df['OCC1950']
# Index([], dtype='object')
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/3323285916.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OCC1950_DUMMY'] = df['OCC1950']
# Index([], dtype='object')

# %% [markdown]
# Finally, merge our aggregated dataframes with their corresponding shapefiles!

# %%
# A function to merge aggregated data with enumeration district shapefiles
def merge_enum(df, shp, label):
    merged_df = pd.merge(shp, df, on=label, how='inner')

    # Turn it into a GeoDataFrame
    gdf = gpd.GeoDataFrame(merged_df, geometry='geometry')

    # Reindex to turn the enumeration district label into a normal column
    gdf.reset_index(drop=True, inplace=True)

    # Make a column with the areas of each district (this will be useful later)
    gdf[f'{label[:4]}_AREA'] = gdf['geometry'].area

    return gdf

# Perform the function for our five censuses

gdf_1900 = merge_enum(df_1900_enumgroupsums, shp1900,label='1900label')
gdf_1910 = merge_enum(df_1910_enumgroupsums, shp1910,label='1910label')
gdf_1920 = merge_enum(df_1920_enumgroupsums, shp1920,label='1920label')
gdf_1930 = merge_enum(df_1930_enumgroupsums, shp1930,label='1930label')
gdf_1940 = merge_enum(df_1940_enumgroupsums, shp1940,label='1940label')
# Out:
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/2068163712.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf[f'{label[:4]}_AREA'] = gdf['geometry'].area
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/2068163712.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf[f'{label[:4]}_AREA'] = gdf['geometry'].area
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/2068163712.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf[f'{label[:4]}_AREA'] = gdf['geometry'].area
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/2068163712.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf[f'{label[:4]}_AREA'] = gdf['geometry'].area
# /var/folders/4n/4pdlrj2d1cz9mxmqmxm71s1c0000gn/T/ipykernel_97596/2068163712.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf[f'{label[:4]}_AREA'] = gdf['geometry'].area

# %%
gdf_1900.head()
# Out:
#    1900label                                           geometry     YEAR  \
# 0   47000168  POLYGON ((-74.01292 40.67732, -74.01142 40.676...  2451000
# 1   47000167  POLYGON ((-74.01416 40.67815, -74.01292 40.677...  2804400
# 2   47000169  POLYGON ((-74.01416 40.67815, -74.01224 40.679...  3412400
# 3   47000175  POLYGON ((-73.99873 40.67648, -73.99537 40.675...  2654300
# 4   47000176  POLYGON ((-74.00136 40.67575, -73.99933 40.675...  2825300
#
#    ISPR  ISWHITE  ISBLACK  ITALYBPL  ISITALIAN  ISWHITE_NON_ITALIAN  ISGERMAN  \
# 0     0     1287        0        35         37                 1250       261
# 1     0     1472        0        36         43                 1429       381
# 2     0     1788        0       208        227                 1561       256
# 3     0     1397        0        33         44                 1353       172
# 4     0     1483        0        87        101                 1382       240
#
#    ...  OCC1950_983  OCC1950_984  OCC1950_985  OCC1950_986  OCC1950_987  \
# 0  ...           48            1            0            0            1
# 1  ...           30            3            0            0            0
# 2  ...           67            0            0            0            0
# 3  ...           81            0            0            0            0
# 4  ...           47            1            0            0            0
#
#    OCC1950_991  OCC1950_995  OCC1950_999  TOTAL_POP  1900_AREA
# 0            0            0          543       1290   0.000010
# 1            0            1          543       1476   0.000005
# 2            0            1          642       1796   0.000008
# 3            0            0          553       1397   0.000008
# 4            0            0          586       1487   0.000030
#
# [5 rows x 340 columns]

# %%
gdf_1930.plot(color=(gdf_1930['ISINDUSTRY'] / gdf_1930['TOTAL_POP']) * 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[323], line 1
# ----> 1 gdf_1930.plot(color=(gdf_1930['ISINDUSTRY'] / gdf_1930['TOTAL_POP']) * 100)
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/geopandas/plotting.py:979, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     977 kind = kwargs.pop("kind", "geo")
#     978 if kind == "geo":
# --> 979     return plot_dataframe(data, *args, **kwargs)
#     980 if kind in self._pandas_kinds:
#     981     # Access pandas plots
#     982     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/geopandas/plotting.py:716, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     713     markersize = df[markersize].values
#     715 if column is None:
# --> 716     return plot_series(
#     717         df.geometry,
#     718         cmap=cmap,
#     719         color=color,
#     720         ax=ax,
#     721         figsize=figsize,
#     722         markersize=markersize,
#     723         aspect=aspect,
#     724         **style_kwds,
#     725     )
#     727 # To accept pd.Series and np.arrays as column
#     728 if isinstance(column, (np.ndarray, pd.Series)):
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/geopandas/plotting.py:470, in plot_series(s, cmap, color, ax, figsize, aspect, **style_kwds)
#     467         facecolor = color_
#     469     values_ = values[poly_idx] if cmap else None
# --> 470     _plot_polygon_collection(
#     471         ax, polys, values_, facecolor=facecolor, cmap=cmap, **style_kwds
#     472     )
#     474 # plot all LineStrings and MultiLineString components in same collection
#     475 lines = expl_series[line_idx]
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/geopandas/plotting.py:184, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     180     kwargs["color"] = color
#     182 _expand_kwargs(kwargs, multiindex)
# --> 184 collection = PatchCollection([_PolygonPatch(poly) for poly in geoms], **kwargs)
#     186 if values is not None:
#     187     collection.set_array(np.asarray(values))
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/collections.py:1881, in PatchCollection.__init__(self, patches, match_original, **kwargs)
#    1878     kwargs['linestyles'] = [p.get_linestyle() for p in patches]
#    1879     kwargs['antialiaseds'] = [p.get_antialiased() for p in patches]
# -> 1881 super().__init__(**kwargs)
#    1883 self.set_paths(patches)
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/collections.py:206, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     203 self._offset_transform = offset_transform
#     205 self._path_effects = None
# --> 206 self._internal_update(kwargs)
#     207 self._paths = None
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/artist.py:1192, in Artist._update_props(self, props, errfmt)
#    1189             if not callable(func):
#    1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
# -> 1192             ret.append(func(v))
#    1193 if ret:
#    1194     self.pchanged()
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/collections.py:784, in Collection.set_facecolor(self, c)
#     782     c = c.lower()
#     783 self._original_facecolor = c
# --> 784 self._set_facecolor(c)
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/collections.py:766, in Collection._set_facecolor(self, c)
#     763 if c is None:
#     764     c = self._get_default_facecolor()
# --> 766 self._facecolors = mcolors.to_rgba_array(c, self._alpha)
#     767 self.stale = True
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/colors.py:512, in to_rgba_array(c, alpha)
#     510         rgba = np.array([to_rgba(cc) for cc in c])
#     511 else:
# --> 512     rgba = np.array([to_rgba(cc) for cc in c])
#     514 if alpha is not None:
#     515     rgba[:, 3] = alpha
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/colors.py:512, in <listcomp>(.0)
#     510         rgba = np.array([to_rgba(cc) for cc in c])
#     511 else:
# --> 512     rgba = np.array([to_rgba(cc) for cc in c])
#     514 if alpha is not None:
#     515     rgba[:, 3] = alpha
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/colors.py:314, in to_rgba(c, alpha)
#     312     rgba = None
#     313 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 314     rgba = _to_rgba_no_colorcycle(c, alpha)
#     315     try:
#     316         _colors_full_map.cache[c, alpha] = rgba
#
# File /opt/anaconda3/envs/data/lib/python3.11/site-packages/matplotlib/colors.py:398, in _to_rgba_no_colorcycle(c, alpha)
#     396 # tuple color.
#     397 if not np.iterable(c):
# --> 398     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     399 if len(c) not in [3, 4]:
#     400     raise ValueError("RGBA sequence should have length 3 or 4")
#
# ValueError: Invalid RGBA argument: 32.08430913348946

# %% [markdown]
# # Part 2. EXPLORATORY DATA ANALYSIS
# We already covered most of the cleaning and unification to be done, so the rest of this EDA will be dedicated to exploratory data visualization

# %% [markdown]
# ## 2a. Graphing
# Let's get a sense of the data we are working with!

# %%
# Plot the count of waterfront jobs over the decades by race group
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='YEAR', hue='DEMO_GROUP', palette='husl')
plt.title("Demographic Populations in Brooklyn (1880-1940)")
plt.xlabel("Year")
plt.ylabel("Population")

plt.legend(title='Decmographic Group', labels= ['Other (unidentified white)','Irish', 'Slavic', 'German', 'Italian', 'Black', 'Puerto Rican'])
plt.show()

# %%
# Plot Stevedoring and general Waterfront Industrial Jobs Over Time 


# Data preparation
wfjob_counts = df2.groupby('YEAR')['ISWATERFRONT'].sum().reset_index()
dockjob_counts = df2.groupby('YEAR')['ISDOCKWORKER'].sum().reset_index()

# Create subplots with 2 rows and 1 column
fig, axes = plt.subplots(2, 1, figsize=(10, 12), sharex=True)

# Plot 1: Waterfront-Linked Jobs Over Time
sns.lineplot(data=wfjob_counts, x='YEAR', y='ISWATERFRONT', ax=axes[0])
axes[0].set_title("Waterfront-Linked Jobs Over Time (1880-1940)")
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Number of Waterfront Jobs")
axes[0].set_ylim(ymin=0)

# Plot 2: Stevedoring Jobs Over Time
sns.lineplot(data=dockjob_counts, x='YEAR', y='ISDOCKWORKER', ax=axes[1])
axes[1].set_title("Stevedoring Jobs Over Time (1880-1940)")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Number of Stevedoring Jobs")
axes[1].set_ylim(ymin=0)

# Show the plots
plt.show()

# %%
df_dock = df[df['ISDOCKWORKER'] == 1]
# isolate just Stevedoring Population

plt.figure()
sns.countplot(data=df_dock, x='YEAR', hue='DEMO_GROUP', palette='husl')
plt.title("Number of Stevdores/Longshoremen Over Time by Race/Ethnicity")
plt.xlabel("Year")
plt.ylabel("Count of Dockworkers")
plt.legend(title='Race/Ethnicity', labels= ['Other (unidentified white)','Irish', 'Slavic', 'German', 'Italian', 'Black', 'Puerto Rican'])

plt.show()

# %%
df_dock = df[df['ISDOCKWORKER'] == 1]
# isolate just Stevedoring Population

plt.figure()
sns.countplot(data=df_dock, x='YEAR', hue='ISIMMIGRANT', palette='husl')
plt.title("Immigrant Longshoremen/Stevedores")
plt.xlabel("Year")
plt.ylabel("Count")

plt.legend(title='Race/Ethnicity', labels= ['Native Born', 'Immigrant'])

plt.show()

# %% [markdown]
# Immigrant Longshoremen by Demographic

# %%
df_immdock = df[(df['ISIMMIGRANT'] == 1)&(df['ISWATERFRONT']==1)]
# isolate just Stevedoring Population

plt.figure()
sns.countplot(data=df_immdock, x='YEAR', hue='DEMO_GROUP', palette='husl')
plt.title("Immigrant Longshoremen/Stevedores by race/ethnicity")
plt.xlabel("Year")
plt.ylabel("Count")

plt.legend(title='Race/Ethnicity', labels= ['Other (unidentified white)','Irish', 'Slavic', 'German', 'Italian', 'Black', 'Puerto Rican'])

plt.show()

# %%
# plot Puerto Rican, Black, and Italian employment categories (waterfront relevant) over time
fig, axes = plt.subplots(3, 1, sharex=True, figsize=(10, 15))

df_pr = df_jobrecorded[df_jobrecorded['ISPR'] == 1]
df_it = df_jobrecorded[df_jobrecorded['ISITALIAN'] == 1]
df_blk = df_jobrecorded[df_jobrecorded['ISBLACK'] == 1]


sns.countplot(data=df_pr, x='YEAR', hue='JOB_GROUP', ax=axes[0])
axes[0].set_title("Puerto Rican Workforce Over Time by occupation")
axes[0].set_xlabel("Year")
axes[0].set_ylabel("Count of Puerto Rican Workers")
axes[0].legend(title='Waterfront Connection', labels=['non-industrial workers', 'general laborers', 'waterfront-linked laborers', 'dockworkers'])


sns.countplot(data=df_blk, x='YEAR', hue='JOB_GROUP', ax=axes[1])
axes[1].set_title("Black Workforce Over Time by occupation")
axes[1].set_xlabel("Year")
axes[1].set_ylabel("Count of Black Workers")
axes[1].legend(title='Waterfront Connection', labels=['non-industrial workers', 'general laborers', 'waterfront-linked laborers', 'dockworkers'])

sns.countplot(data=df_it, x='YEAR', hue='JOB_GROUP', ax=axes[2])
axes[2].set_title("Italian Workforce Over Time by occupation")
axes[2].set_xlabel("Year")
axes[2].set_ylabel("Count of Italian Workers")
axes[2].legend(title='Waterfront Connection', labels=['non-industrial workers', 'general laborers', 'waterfront-linked laborers', 'dockworkers'])


plt.show()

# %%
# plot Black employment categories (related to waterfront) over time

df_blk = df_jobrecorded[df_jobrecorded['ISBLACK'] == 1]
# isolate just Black population

plt.figure()
sns.countplot(data=df_blk, x='YEAR', hue='JOB_GROUP')
plt.title("Black Workforce Over Time by occupation")
plt.xlabel("Year")
plt.ylabel("Count of Black Workers")

plt.legend(title='Waterfront Connection', labels=['non-industrial workers', 'general laborers', 'waterfront-linked laborers', 'dockworkers'])

plt.show()

# %%
df_pr['OCC1950'].value_counts().head(15)
# Out:
# OCC1950
# 690    2546
# 970    2243
# 720     420
# 979     389
# 390     378
# 790     331
# 673     286
# 643     284
# 290     253
# 940     248
# 784     221
# 490     215
# 980     194
# 990     175
# 780     164
# Name: count, dtype: int64

# %%
# plot Same thing but for Italian Laborers 

df_it = df_jobrecorded[df_jobrecorded['ISITALIAN'] == 1]

plt.figure()
sns.countplot(data=df_it, x='YEAR', hue='JOB_GROUP')
plt.title("Italian Workforce Over Time by occupation")
plt.xlabel("Year")
plt.ylabel("Count of Italian Workers")

plt.legend(title='Waterfront Connection', labels=['non-industrial workers', 'general laborers', 'waterfront-linked laborers', 'dockworkers'])

plt.show()

# %%
# plot puerto rican involvement in industrial labor
dfpr_plot = df_pr.groupby(['YEAR', 'ISDOCKWORKER']).size().reset_index().pivot(columns='ISDOCKWORKER', index='YEAR', values=0)

dfpr_plot

dfpr_plot.plot(kind='bar', stacked=True, title='Puerto Rican Stevedoring Population')
plt.legend(["Non-Stevedore job", "Stevedore job"], title="Labor Type")

# %% [markdown]
# Finally, let's make a heatmap of that percentage dataframe we made earlier. It still isn't the perfect way of visualizing the imbalances, and I may need to refine my categorization a bit more, but it's a step in the right direction.

# %%
plt.figure()
sns.heatmap(dfpercentages, annot=True, fmt=".1f")

plt.title("Heatmap of Job Group Percentages", fontsize=16)
plt.xlabel("Job Groups", fontsize=12)
plt.ylabel("Year and Demographic Group", fontsize=12)

plt.tight_layout()
plt.show()

# Interesting to see how, in Brooklyn, a much larger share of Italians are Longshoremen, while Black and Puerto Rican workers are disporportionately funnelled to more basic labor occupations

# %% [markdown]
# This result is very interesting. There is some muddy overlap and discrepancy between/among the "Operative" and "Laborer" occupation classification: It is sometimes hard to tell what "Operative" Jobs are more more technical jobs, and which are more general factory machinery jobs.
